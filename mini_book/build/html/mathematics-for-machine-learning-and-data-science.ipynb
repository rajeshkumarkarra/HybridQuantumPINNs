# %% [markdown]
# <a href="https://www.kaggle.com/code/rajeshkumarkarra/mathematics-for-machine-learning-and-data-science?scriptVersionId=238881152" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import numpy as np
one_dimensional_arr = np.array([10, 12])
print(one_dimensional_arr)
# Out:
# [10 12]

# %%
one_dimensional_arr = np.array([10, 12])
print(one_dimensional_arr)
# Out:
# [10 12]
